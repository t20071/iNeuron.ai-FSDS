# %% [markdown]
# # Assignment 1
#
# **1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.**
#
# **Answer**
# 1. \* ..................expression
# 1. 'hello' ..................value
# 1. -87.8..................value
# 1. 4 ..................value
# 1. / ..................expression
# 1. \+..................expression
# 1. 6 ..................value
#
#
# **2. What is the difference between string and variable?**
#
# **Answer**
# 1. string - string is a data type which write in single or double quatation.
# 1. variable - Is a storing element of any data type in python.
#
# **3. Describe three different data types.**
#
# **Answer**
#
# 1. int - It is a numerical value. It can contain any positive or negative whole number (without fraction or decimal.)
# 1. list -
#
# **4. What is an expression made up of? What do all expressions do?**
#
# **Answer**
# Expression is made up of operator,variable and value. eg - ```3+2 = 5``` is a expression in which 3 and 2 are value and + is a methamatical operator.
# *If we ask to evaluate the len() of expression then it will give output as length of the input given in len.
#
# **5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?**
#
# **Answer**
# *Expression is made up of operator,variable and value. eg - ```2.9, a + 5, (3 + 5) / 4.```
# *Statement represent a motion or command e.g print statements eg - ```print("Hello")```
#
# **6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon +=1**
#
# **Answer**  bacon = 23
#
# **7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3**
#
# **Answer**
# 1. 'spam' + 'spamspam' = 'spamspamspam'
# 1. 'spam' * 3 =  'spamspamspam'
#
# **8. Why is eggs a valid variable name while 100 is invalid?**
#
# **Answer**
#
# Variable naming rules...
# >Variable name should not start from numerical value and any symbol.
#
#
#
# **9. What three functions can be used to get the integer, floating-point number, or string version of a value?**
#
# **Answer**
# 1. int()
# 1. float()
# 1. str()
#
#
# **10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'**
#
# **Answer**
#
# ```'I have eaten ' + str(99) + ' burritos.'```
