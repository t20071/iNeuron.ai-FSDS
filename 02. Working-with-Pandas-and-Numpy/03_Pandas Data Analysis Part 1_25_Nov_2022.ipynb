# %% [markdown]
# # Pandas Data Analysis Part 1
# **Friday, 25 November 2022**

# %%
import pandas as pd 
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# initial insite
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Age and Cabin less number record so there is null value in it.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# series similar to list

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
col_name = df.dtypes[df.dtypes == "object"].index
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# pandas profiling is more accurate

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # add a new column

# %%
df['ineuron']= 'Sharad'
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][0:15:2] # only 15 record
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df[['Name']][0:15:2]
# Out:
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 2                              Heikkinen, Miss. Laina
# 4                            Allen, Mr. William Henry
# 6                             McCarthy, Mr. Timothy J
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Sandstrom, Miss. Marguerite Rut
# 12                     Saundercock, Mr. William Henry
# 14               Vestrom, Miss. Hulda Amanda Adolfina

# %%
df['Name'][43]
# Out:
# 'Laroche, Miss. Simonne Marie Anne Andree'

# %%
df[df['Age'].isnull() == True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df[df['Age'].isnull() == True].index)
# Out:
# 177

# %%
ind = df[df['Age'].isnull() == True].index
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# # Que. - Person name who has pay highest fare?

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
bool_val = df['Fare'] == max(df['Fare'])

# %%
df[bool_val]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258  Sharad
# 679  Sharad
# 737  Sharad

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron
# 0      0         A/5 21171   7.2500   NaN        S  Sharad
# 1      0          PC 17599  71.2833   C85        C  Sharad
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Sharad
# 3      0            113803  53.1000  C123        S  Sharad
# ...

# %% [markdown]
# # Questions
#
# q1.Find out how many male and female passenge was onboarded?
#
# q2. How many survived
#
# q3. how many casualaties
#
# q4. name the person who is the eldest one
#
# q5. how many passenger do we have in the first, second and third class
#
# q6. how many person we have whose name starts with 's'
#
# q7. try to create a new column which is a summation of 'Sibsp' and 'parch'
#
# q8. how many person do we have below age of 25
#
# q9. how many person died whose age was less than 40
#
# q10. from a cabin column seperate text and numeric value

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron
# 0      0         A/5 21171   7.2500   NaN        S  Sharad
# 1      0          PC 17599  71.2833   C85        C  Sharad
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Sharad
# 3      0            113803  53.1000  C123        S  Sharad
# ...

# %% [markdown]
# > q1.Find out how many male and female passenge was onboarded?
# > answer - (Male,Female) = (577, 314)

# %%
df_m = df[df['Sex']=='male']
df_F = df[df['Sex']=='female']
len(df_m), len(df_F)
# Out:
# (577, 314)

# %%
# solution1 from sudhansu 
df['Sex'] # it is a series 
# group by and count function 
df['Sex'].value_counts() # this method is the combination of count and group  by method
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# solution2  from sudhansu  
df.groupby('Sex')
df.groupby('Sex').count()
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %% [markdown]
# > q2. How many survived
# > answer - 342

# %%
df_sur = df[df['Survived'] == 1] # this is filter method
len(df_sur)
# Out:
# 342

# %%
# sudh
df.groupby('Survived')['Survived'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# > q3. how many casualaties
# > answer - 549

# %%
df_C = df[df['Survived'] == 0]
len(df_C)
# Out:
# 549

# %% [markdown]
# > q4. name the person who is the eldest one
# > Answer -  Age: 80.0
# Name:Barkworth, Mr. Algernon Henry Wilson

# %%
con_80 = df['Age'] == max(df['Age'])
df[con_80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked ineuron
# 630  male  80.0      0      0  27042  30.0   A23        S  Sharad

# %%
# anothe solutjion 
cond = df['Age'] == df['Age'].max()
df[cond]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# > q5. how many passenger do we have in the first, second and third class
# > answer -

# %%
# first class
len(df[df['Pclass']== 1])
# Out:
# 216

# %%
# second class
len(df[df['Pclass']== 2])
# Out:
# 184

# %%
# third class
len(df[df['Pclass']== 3])
# Out:
# 491

# %%
# anothe solut
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# > q6. how many person we have whose name starts with 's'
# > Answer - 86

# %%
series1 = df['Name'].str.startswith('S')
df[series1]
len(df[series1])
# Out:
# 86

# %%
series1 = df['Name'].str.startswith('s')
df[series1]
len(df[series1])
# Out:
# 0

# %% [markdown]
# > q7. try to create a new column which is a summation of 'Sibsp' and 'parch'
# > answer -

# %%
df['summation'] = df.SibSp + df.Parch

# %%
df[['SibSp','Parch','summation']]
# Out:
#      SibSp  Parch  summation
# 0        1      0          1
# 1        1      0          1
# 2        0      0          0
# 3        1      0          1
# 4        0      0          0
# ..     ...    ...        ...
# 886      0      0          0
# 887      0      0          0
# 888      1      2          3
# 889      0      0          0
# 890      0      0          0
#
# [891 rows x 3 columns]

# %%
# another solution
df['summation'] = df['SibSp'] + df['Parch']

# %% [markdown]
# > q8. how many person do we have below age of 25
# > Answer - 278

# %%
condition = df['Age'] < 25 # called filter operation
df1 = df[condition]
len(df1)
# Out:
# 278

# %% [markdown]
# > q9. how many person died whose age was less than 40
# > Answer -  322

# %%
condition = (df['Survived'] == 0)
df_not_s = df[condition]
df_not_s
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
condition = (df_not_s['Age'] < 40)
df_not_s[condition]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# ...

# %%
len(df_not_s[condition])
# Out:
# 322

# %%
# another solution 
filtr = (df['Survived'] == 0) & (df['Age']<40)
len(df[filtr])
# Out:
# 322

# %% [markdown]
# > q10. from a cabin column seperate text and numeric value
# > Answer -

# %%
import re 
pattern = re.compile('([a-zA-Z]+)')
df['Cabinstring'] = df['Cabin'].str.extract(pattern)
df['CabinNumeric'] = df['Cabin'].str.replace(pattern,'')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron  summation  \
# 0      0         A/5 21171   7.2500   NaN        S  Sharad          1
# 1      0          PC 17599  71.2833   C85        C  Sharad          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Sharad          0
# ...

# %% [markdown]
# [https://github.com/iNeuronai/same-resume-year-wise](https://github.com/iNeuronai/same-resume-year-wise)
#
# 45;52[https://learn.ineuron.ai/lesson/Pandas-Data-Analysis-Part-2/62eaa6ba766d655b07316a31/course/Full-Stack-Data-Science-BootCamp-2.0/62eaa6ba766d6539c53164bd](https://learn.ineuron.ai/lesson/Pandas-Data-Analysis-Part-2/62eaa6ba766d655b07316a31/course/Full-Stack-Data-Science-BootCamp-2.0/62eaa6ba766d6539c53164bd)
#
# Read all the resume from ineuron git in pdf, word and try to create a dataframe with resume name as index value, and in  column  and i am expection email_id, linked id and skills ?

# %% [markdown]
# # 26 Nov 2022

# %% [markdown]
# Data source
#
# [https://archive.ics.uci.edu/ml/datasets/bank+marketing](https://archive.ics.uci.edu/ml/datasets/bank+marketing)

# %%
import pandas as pd
df = pd.read_csv('bank.csv',sep =';')
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# ### Questions about dataset
#
# q1. How many compaign available in this dataset?
#
# q2. How many users do we have with housing and personal loan?
#
# q3. How many do we have whose age is 60 +?
#
# q4. In which month we have targeted most of the customers?
#
# q5.  Which mode of call giving more result?
#
# q6. How many enterprenuer do we have in this dataset?
#
# q7. How many customers do we have with negativa balance?
#
# q8. Prepare a group of data based on education level?

# %% [markdown]
# **q1. How many compaign available in this dataset?
# Answer -** There are

# %%
df['campaign'].unique()
len(df['campaign'].unique())
# Out:
# 32

# %%
# another solution 
df['campaign']
list(df['campaign'])
set(list(df['campaign']))
len(set(list(df['campaign'])))
# Out:
# 32

# %% [markdown]
# **q2. How many users do we have with housing and personal loan?
# Answer-**
# PL = 691
# HL = 2559

# %%
df_pl = df[df['loan'] == 'yes']
df_pl
len(df_pl)
# Out:
# 691

# %%
df_hl = df[df['housing'] == 'yes']
df_hl
len(df_hl)
# Out:
# 2559

# %%
# another solution
df['housing'].value_counts() # answer is yes one
# Out:
# yes    2559
# no     1962
# Name: housing, dtype: int64

# %%
df['loan'].value_counts() # answer is yes one
# Out:
# no     3830
# yes     691
# Name: loan, dtype: int64

# %%
# having both personal and housing loan
filter1 = (df['housing']=='yes') & (df['loan']=='yes') 
df[filter1]
len(df[filter1])
# Out:
# 406

# %% [markdown]
# **q3. How many do we have whose age is 60 +?
# Answer -** 127

# %%
df_60 = df[df['age']>60]
df_60
len(df_60)
# Out:
# 127

# %% [markdown]
# **q4. In which month we have targeted most of the customers?
# Answer-**
# There are 521 people subscribed. and mostly in may
# top	may
# freq	93

# %%
df_y = df[df['y']== 'yes']  # dataframe where result outcome is yes
df_m = df_y['month']  # select all the month column from df_y
df_m.describe()       # after descibing we get the result
# Out:
# count     521
# unique     12
# top       may
# freq       93
# Name: month, dtype: object

# %%
# another solution 
df['month'].value_counts()
df['month'].value_counts().index[0]
# Out:
# 'may'

# %% [markdown]
# **q5. Which mode of call giving more result?
# Answer**
# top       cellular
# freq           416

# %%
df_y = df[df['y']== 'yes']  # dataframe where result outcome is yes
df_contact = df_y['contact']
df_contact.describe()
# Out:
# count          521
# unique           3
# top       cellular
# freq           416
# Name: contact, dtype: object

# %%
# another solution by sudh
df_cont_y = df.groupby(['contact','y']).count()
df_cont_y.loc['cellular']
df_cont_y.loc['cellular','yes']
df_cont_y.loc['cellular','yes'][0]
# Out:
# 416

# %% [markdown]
# **q6. How many enterprenuer do we have in this dataset?
# answer** 168

# %%
df_enterprenuer = df[df['job'] == 'entrepreneur']
df_enterprenuer
len(df_enterprenuer)
# Out:
# 168

# %% [markdown]
# **q7. How many customers do we have with negativa balance?
# Answer**
# 366

# %%
df_negative_balance = df[df['balance']< 0]
df_negative_balance
len(df_negative_balance)
# Out:
# 366

# %% [markdown]
# **q8. Prepare a group of data based on education level?
# Answer-**

# %%
df['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
l = []
for i in df['education'].unique():
    l.append(df[df['education'] == i])

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...
