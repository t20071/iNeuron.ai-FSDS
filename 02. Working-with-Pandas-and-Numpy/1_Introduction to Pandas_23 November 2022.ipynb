# %% [markdown]
# # Pandas
# **23 November 2022**
# [https://www.youtube.com/watch?v=ciCe4_-XRME](https://www.youtube.com/watch?v=ciCe4_-XRME)

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is Windows SSD
#  Volume Serial Number is FCA4-BF44
#
#  Directory of C:\Users\HP\1AI iNeuron
#
# 23-11-2022  10:02 PM    <DIR>          .
# 23-11-2022  10:02 PM    <DIR>          ..
# 23-11-2022  03:47 PM    <DIR>          .ipynb_checkpoints
# 23-11-2022  10:02 PM            80,118 023_Pandas_23 November 2022.ipynb
# 22-11-2022  09:11 AM    <DIR>          Assignment-main
# 23-11-2022  04:44 PM    <DIR>          Classes-main
# 23-11-2022  09:47 PM             1,589 contacts.csv
# 23-11-2022  07:15 PM         3,148,166 machine-readable-business-employment-data-june-2022-quarter.csv
# 23-11-2022  09:37 PM               177 MES#.csv
# 23-11-2022  09:34 PM               177 MES.csv
# 23-11-2022  09:40 PM               177 MES@.csv
# 22-11-2022  08:49 AM                 0 untitled.txt
# 21-11-2022  05:07 PM           236,180 vocab.enron.txt
# 21-11-2022  05:07 PM            55,467 vocab.kos.txt
# 21-11-2022  05:07 PM           100,807 vocab.nips.txt
# ...

# %%
# pd.read,press tab there is lot option
pd.read_csv('MES.csv')
# Out:
#          Name@email@contact no@address
# 0  Sharad@sharad@gmail.com@20071@MANDI
# 1  Anjani@anjani@gmail.com@20072@MANDI
# 2    vinay@vinay@gmail.com@20073@MANDI
# 3  Mukesh@mukesh@gmail.com@20074@MANDI

# %%
pd.read_csv('machine-readable-business-employment-data-june-2022-quarter.csv').tail(5)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 20249          0  Business Data Collection - BDC
# 20250          0  Business Data Collection - BDC
# 20251          0  Business Data Collection - BDC
# 20252          0  Business Data Collection - BDC
# 20253          0  Business Data Collection - BDC
#
#                                               Group  \
# 20249  Territorial authority by employment variable
# 20250  Territorial authority by employment variable
# 20251  Territorial authority by employment variable
# ...

# %% [markdown]
# Data source
# [https://github.com/codeforamerica/ohana-api](https://github.com/codeforamerica/ohana-api)

# %%
pd.read_csv('contacts.csv').head()
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   1          1.0              NaN         NaN       Susan Houston
# 1   2          1.0              NaN         NaN  Christina Gonzalez
# 2   3          2.0              NaN         NaN        Brenda Brown
# 3   4          3.0              NaN         NaN  Howard Lader, LCSW
# 4   5          4.0              NaN         NaN  Kimberly Pesavento
#
#                               title email department
# 0  Director of Older Adult Services   NaN        NaN
# 1                   Center Director   NaN        NaN
# 2  Director, Second Career Services   NaN        NaN
# 3   Manager, Senior Peer Counseling   NaN        NaN
# 4            Director of Visitation   NaN        NaN

# %%
pd.read_csv(r'C:\Users\HP\Downloads\ohana-api-master\ohana-api-master\data\sample-csv\locations.csv').tail(3)
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 19            NaN                                           no phone
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# 19               NaN                                              NaN
# 20               NaN                                              NaN
# 21  info@example.org  Cantonese, Russian, Spanish, Tagalog, Taiwanese
#
#      latitude   longitude                    name  \
# ...

# %%
pd.read_csv(r'C:\Users\HP\Downloads\ohana-api-master\ohana-api-master\data\sample-csv\addresses.csv').tail(3)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 18  19           19         19 West 39th Avenue        NaN      San Mateo
# 19  20           21          123 El Camino Real        NaN        Belmont
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 18             CA       94403      US
# 19             CA       94002      US
# 20             CA       94103      US

# %% [markdown]
# #### very very first row will be title indexes
# 1. use pd when data is in structure if not use open in read and write mode.
# 2. Entire table called dataframe.
# 1. pd understand data type.

# %%
df = pd.read_csv(r'C:\Users\HP\Downloads\ohana-api-master\ohana-api-master\data\sample-csv\addresses.csv').tail(10)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('contacts.csv').head()
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   1          1.0              NaN         NaN       Susan Houston
# 1   2          1.0              NaN         NaN  Christina Gonzalez
# 2   3          2.0              NaN         NaN        Brenda Brown
# 3   4          3.0              NaN         NaN  Howard Lader, LCSW
# 4   5          4.0              NaN         NaN  Kimberly Pesavento
#
#                               title email department
# 0  Director of Older Adult Services   NaN        NaN
# 1                   Center Director   NaN        NaN
# 2  Director, Second Career Services   NaN        NaN
# 3   Manager, Senior Peer Counseling   NaN        NaN
# 4            Director of Visitation   NaN        NaN

# %% [markdown]
# delete the title row

# %%
pd.read_csv('contacts.csv').head()
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   1          1.0              NaN         NaN       Susan Houston
# 1   2          1.0              NaN         NaN  Christina Gonzalez
# 2   3          2.0              NaN         NaN        Brenda Brown
# 3   4          3.0              NaN         NaN  Howard Lader, LCSW
# 4   5          4.0              NaN         NaN  Kimberly Pesavento
#
#                               title email department
# 0  Director of Older Adult Services   NaN        NaN
# 1                   Center Director   NaN        NaN
# 2  Director, Second Career Services   NaN        NaN
# 3   Manager, Senior Peer Counseling   NaN        NaN
# 4            Director of Visitation   NaN        NaN

# %%
pd.read_csv('contacts.csv',header =None ).head()
# Out:
#     0            1                2           3                   4  \
# 0  id  location_id  organization_id  service_id                name
# 1   1            1              NaN         NaN       Susan Houston
# 2   2            1              NaN         NaN  Christina Gonzalez
# 3   3            2              NaN         NaN        Brenda Brown
# 4   4            3              NaN         NaN  Howard Lader, LCSW
#
#                                   5      6           7
# 0                             title  email  department
# 1  Director of Older Adult Services    NaN         NaN
# 2                   Center Director    NaN         NaN
# 3  Director, Second Career Services    NaN         NaN
# 4   Manager, Senior Peer Counseling    NaN         NaN

# %% [markdown]
# ### naming the title

# %%
pd.read_csv('contacts.csv',names = ['a','b','c','d','e','f','g','h'] ).head()
# Out:
#     a            b                c           d                   e  \
# 0  id  location_id  organization_id  service_id                name
# 1   1            1              NaN         NaN       Susan Houston
# 2   2            1              NaN         NaN  Christina Gonzalez
# 3   3            2              NaN         NaN        Brenda Brown
# 4   4            3              NaN         NaN  Howard Lader, LCSW
#
#                                   f      g           h
# 0                             title  email  department
# 1  Director of Older Adult Services    NaN         NaN
# 2                   Center Director    NaN         NaN
# 3  Director, Second Career Services    NaN         NaN
# 4   Manager, Senior Peer Counseling    NaN         NaN

# %%
pd.read_csv('contacts.csv',names = ['a','b','c','d','e','f','g'] ).head()
# Out:
#               a                b           c                   d  \
# id  location_id  organization_id  service_id                name
# 1             1              NaN         NaN       Susan Houston
# 2             1              NaN         NaN  Christina Gonzalez
# 3             2              NaN         NaN        Brenda Brown
# 4             3              NaN         NaN  Howard Lader, LCSW
#
#                                    e      f           g
# id                             title  email  department
# 1   Director of Older Adult Services    NaN         NaN
# 2                    Center Director    NaN         NaN
# 3   Director, Second Career Services    NaN         NaN
# 4    Manager, Senior Peer Counseling    NaN         NaN

# %%
pd.read_csv(r'contacts.csv',names = ['a','b','c','d','e','f','g','h','sdlfjsajf']).head()
# Out:
#     a            b                c           d                   e  \
# 0  id  location_id  organization_id  service_id                name
# 1   1            1              NaN         NaN       Susan Houston
# 2   2            1              NaN         NaN  Christina Gonzalez
# 3   3            2              NaN         NaN        Brenda Brown
# 4   4            3              NaN         NaN  Howard Lader, LCSW
#
#                                   f      g           h  sdlfjsajf
# 0                             title  email  department        NaN
# 1  Director of Older Adult Services    NaN         NaN        NaN
# 2                   Center Director    NaN         NaN        NaN
# 3  Director, Second Career Services    NaN         NaN        NaN
# 4   Manager, Senior Peer Counseling    NaN         NaN        NaN

# %%
pd.read_csv('MES.csv')
# Out:
#          Name@email@contact no@address
# 0  Sharad@sharad@gmail.com@20071@MANDI
# 1  Anjani@anjani@gmail.com@20072@MANDI
# 2    vinay@vinay@gmail.com@20073@MANDI
# 3  Mukesh@mukesh@gmail.com@20074@MANDI

# %%
pd.read_csv('MES#.csv')
# Out:
#          Name#email#contact no#address
# 0  Sharad#sharad@gmail.com#20071#MANDI
# 1  Anjani#anjani@gmail.com#20072#MANDI
# 2    vinay#vinay@gmail.com#20073#MANDI
# 3  Mukesh#mukesh@gmail.com#20074#MANDI

# %%
pd.read_csv('MES#.csv',delimiter = '#')
# Out:
#      Name             email  contact no address
# 0  Sharad  sharad@gmail.com       20071   MANDI
# 1  Anjani  anjani@gmail.com       20072   MANDI
# 2   vinay   vinay@gmail.com       20073   MANDI
# 3  Mukesh  mukesh@gmail.com       20074   MANDI

# %%
pd.read_csv('MES#.csv',sep = '#')
# Out:
#      Name             email  contact no address
# 0  Sharad  sharad@gmail.com       20071   MANDI
# 1  Anjani  anjani@gmail.com       20072   MANDI
# 2   vinay   vinay@gmail.com       20073   MANDI
# 3  Mukesh  mukesh@gmail.com       20074   MANDI

# %%
pd.read_csv('MES@.csv')
# Out:
#          Name@email@contact no@address
# 0  Sharad@sharad@gmail.com@20071@MANDI
# 1  Anjani@anjani@gmail.com@20072@MANDI
# 2    vinay@vinay@gmail.com@20073@MANDI
# 3  Mukesh@mukesh@gmail.com@20074@MANDI

# %%
pd.read_csv('MES@.csv',sep = '@')
# Out:
#           Name      email  contact no address
# Sharad  sharad  gmail.com       20071   MANDI
# Anjani  anjani  gmail.com       20072   MANDI
# vinay    vinay  gmail.com       20073   MANDI
# Mukesh  mukesh  gmail.com       20074   MANDI

# %%
df = pd.read_csv('MES#.csv',sep = '#')
df
# Out:
#      Name             email  contact no address
# 0  Sharad  sharad@gmail.com       20071   MANDI
# 1  Anjani  anjani@gmail.com       20072   MANDI
# 2   vinay   vinay@gmail.com       20073   MANDI
# 3  Mukesh  mukesh@gmail.com       20074   MANDI

# %%
df1 = pd.read_csv('MES#.csv',sep = '#',skiprows=[4,3])
df1
# Out:
#      Name             email  contact no address
# 0  Sharad  sharad@gmail.com       20071   MANDI
# 1  Anjani  anjani@gmail.com       20072   MANDI

# %%
df2 = pd.read_csv('MES#.csv',sep = '#',skiprows=[0,3])
df2
# Out:
#    Sharad  sharad@gmail.com  20071  MANDI
# 0  Anjani  anjani@gmail.com  20072  MANDI
# 1  Mukesh  mukesh@gmail.com  20074  MANDI

# %%
df = pd.read_csv('contacts.csv')
df.tail()
# Out:
#     id  location_id  organization_id  service_id               name  \
# 26  27         19.0              NaN         NaN    Sharon Petersen
# 27  28         21.0              NaN         NaN             Moncef
# 28  29         22.0              NaN         NaN  Suzanne Badenhoop
# 29  32          NaN              8.0         NaN   Elizabeth Feeney
# 30  36          NaN              NaN        22.0          Joe Smith
#
#                   title                   email             department
# 26        Administrator                     NaN                    NaN
# 27                  NaN                     NaN   Office of Innovation
# 28      Board President     suzanne@example.com              Referrals
# 29                  CEO     e.feeney@foobar.org             Operations
# 30  CalFresh Specialist  john.smith@example.org  CalFresh Applications

# %%
df.dtypes
# Out:
# id                   int64
# location_id        float64
# organization_id    float64
# service_id         float64
# name                object
# title               object
# email               object
# department          object
# dtype: object

# %% [markdown]
# #### object = string

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'organization_id', 'service_id', 'name', 'title',
#        'email', 'department'],
#       dtype='object')

# %%
df['email'].tail()
# Out:
# 26                       NaN
# 27                       NaN
# 28       suzanne@example.com
# 29       e.feeney@foobar.org
# 30    john.smith@example.org
# Name: email, dtype: object

# %%
a = df['name'].head()
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# table contains dataframe and series
# series - single column or row then pandas show series, it is like list
# dataframe is the combination of multiple series.

# %%
df['name','email']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'email')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
b = df[['name','email']].head()
b
# Out:
#                  name email
# 0       Susan Houston   NaN
# 1  Christina Gonzalez   NaN
# 2        Brenda Brown   NaN
# 3  Howard Lader, LCSW   NaN
# 4  Kimberly Pesavento   NaN

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
c =df[['email']].tail()
c
# Out:
#                      email
# 26                     NaN
# 27                     NaN
# 28     suzanne@example.com
# 29     e.feeney@foobar.org
# 30  john.smith@example.org

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('MES.xlsx')
# Out:
#      Name             email  contact no address
# 0  Sharad  sharad@gmail.com       20071   MANDI
# 1  Anjani  anjani@gmail.com       20072   MANDI
# 2   vinay   vinay@gmail.com       20073   MANDI
# 3  Mukesh  mukesh@gmail.com       20074   MANDI

# %%
pd.read_excel('LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %% [markdown]
# ### xlsx
# Data source
# [https://github.com/finbourne/sample-excel](https://github.com/finbourne/sample-excel)

# %%
pd.read_excel('LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name= 'Create your instrument universe')
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3     Active
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8     Active
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8     Active
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57     Active
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05     Active
#
# ...

# %%
df = pd.ExcelFile('LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx')
df.sheet_names
# Out:
# ['Create Portfolio',
#  'Introduction',
#  'Create your instrument universe',
#  'Add your take on balances',
#  'Create your test environment',
#  'Make live trades in production',
#  'Add some test transactions',
#  'Inputs']

# %%
# read all sheets
for i in df.sheet_names:
    pd.read_excel('LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name= i)

# %%
pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# go to raw option 
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
