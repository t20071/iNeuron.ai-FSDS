# %% [markdown]
# # Graph

# %% [markdown]
# ### 12 Python Data Visualization Libraries to Explore for Business Analysis
# Matplotlib.
# Seaborn.
# Plotnine(ggplot)
# Bokeh.
# pygal.
# **Plotly.**
# geoplotlib.
# Gleam.

# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
np.random.randn(1000)
pd.DataFrame(np.random.randn(1000))
df = pd.DataFrame(np.random.randn(1000),columns = ['Data'])
df
# Out:
#          Data
# 0    0.878932
# 1   -1.770175
# 2   -0.662888
# 3   -0.059351
# 4   -1.593629
# ..        ...
# 995 -0.244799
# 996 -0.658335
# 997 -1.853943
# 998 -0.622929
# 999  0.072239
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(365),columns = ['Data'],index = pd.date_range('2023/01/01',periods = 365))
df
# Out:
#                 Data
# 2023-01-01 -0.577897
# 2023-01-02  0.500460
# 2023-01-03  0.738243
# 2023-01-04  0.121805
# 2023-01-05 -0.457886
# ...              ...
# 2023-12-27 -0.043473
# 2023-12-28 -0.923811
# 2023-12-29  0.349339
# 2023-12-30 -0.110792
# 2023-12-31 -0.281624
#
# [365 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize =(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# > plt is not good one so will focus on plotly after plt.

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# top 5 data graph
df.head().plot(kind = 'bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
# graph form row index 5 to 10 
df.iloc[5:11].plot(kind = 'bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[5]].plot(kind = 'bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[5]].plot(kind = 'barh',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df['sepal_length'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['petal_length'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['petal_width'].plot(kind = 'hist',orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.hist(figsize = (20,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10),color = 'g')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10),color = 'g',alpha = 0.7)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind = 'box',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind='box',color = {'boxes': 'g','whiskers':'r'},figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',color = {'boxes': 'g','whiskers':'r'},figsize = (20,10),vert = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Area Graph

# %%
df.plot(kind = 'area',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'line',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area',figsize = (20,10),stacked = False) # contrast
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area',figsize = (20,10),alpha = 0.5,stacked = False) # contrast
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter plot

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length',figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_width',figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'petal_width',figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'petal_width',figsize = (10,5),s = 400)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'petal_width',figsize = (10,5),s = df['petal_width']*400)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10,C = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # pie plot

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iloc[[0]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
df1 = df.drop(columns = 'species').iloc[0]
df1
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# # plotly

# %%
! pip install plotly

# %%
! pip install cufflinks

# %%
import cufflinks as cf

# %% [markdown]
# > cufflinks is offline version of plotly.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
! pip install chart_studio

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="6d263742-bab2-43ea-b46f-7f21f0f8419e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'petal_length' )
# Out:
# <div>                            <div id="684b1b95-e316-4835-81ce-972ead2751c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'petal_length', mode = 'markers' )
# Out:
# <div>                            <div id="77f80977-7c70-4383-9a7e-c91050dc5a65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter',mode = 'markers', size = 6)
# Out:
# <div>                            <div id="1c933541-c3da-434e-978d-0187e0ee69d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'bubble', x = 'sepal_length', y = 'petal_length', size = 'sepal_width')
# Out:
# <div>                            <div id="e76b725b-9d29-4566-b756-95dc00eff3e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="c1bbd475-014b-407c-9bde-5b481251f176" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(kind = 'scatter3d', x = 'sepal_length', y = 'sepal_length', z = 'petal_length')
# Out:
# <div>                            <div id="3b5c0ed5-1572-406f-9fb5-a40dbd9fc768" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind = 'scatter3d', x = 'sepal_length', y = 'sepal_length', z = 'petal_length')
# Out:
# <div>                            <div id="dcfe3d65-b7ec-4849-b32a-00b3d787f8e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iplot(kind = 'bubble3d', x = 'sepal_length', y = 'sepal_length', z = 'petal_length',size = 'petal_width')
# Out:
# <div>                            <div id="1f6a5b13-c070-4a38-9c68-d0980bbe6150" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Homework
# 1. Try to explore map graph and try to show and example? - weather dataset, pole dataset, covid dataset.(2-3 example)
